# %% [markdown]
# ## Data Collection for Research Question 2
#
# Question: Is there a correlation between the number of hotels and other short-term rental options and the number of cafes, restaurants (other amenities used by tourists)?
#
# Data collected: yearly counts of the following amenities and areas between 2013 and 2024 (inclusive) from OpenStreetMaps
#
# _Note: yearly counts are calculated as mean of monthly count for each month in a given year. Monthly count is the count at the 1st day of the month._
#
# | Amenities | Areas|
# | --- | --- |
# | Cafe | London |
# | Restaurant | Bath |
# | Car rental | St. Albans |

# %%
import requests
import pandas as pd
import statistics
from pathlib import Path

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json][date:"2013-01-01T00:00:00Z"];
area[name="London"][wikipedia="en:London"];
node["amenity"="cafe"](area);
out;
"""

# %%
def construct_osm_area_filter(area):
    filter = {"area_filter": "", "node_area_filter": "(area)"}
    match area:
        case "London":
            filter["area_filter"] = "area[name=\"London\"][wikipedia=\"en:London\"];"
        case "St_Albans":
            filter["area_filter"] = "area[name=\"St Albans\"][boundary = \"public_transport\"];"
        case "Bath":
            filter["node_area_filter"] = "(51.2739,-2.43,51.4391,-2.2834)"
    return filter

# %%
def construct_osm_amenity_query(date, area, amenity, out_type): 
    out = "out" if out_type == "" else f"out {out_type}" 
    area_filter = construct_osm_area_filter(area)
    amenity_filter =  f"\"amenity\"=\"{amenity}\"" if amenity != "hotel" else "\"tourism\"=\"hotel\""
    overpass_query = f"""
        [out:json][date:"{date}"];
        {area_filter["area_filter"]}
        node[{amenity_filter}]{area_filter["node_area_filter"]};
        {out};
    """
    return overpass_query

# %%
def get_osm_amenity_data(date, area, amenity, out_type = ""):
    overpass_query = construct_osm_amenity_query(date, area, amenity, out_type)
    response = requests.get(overpass_url, params={'data': overpass_query})
    data = response.json()
    return data["elements"]

# %%
def get_osm_amenity_data(date, area, amenity, out_type = ""):
    overpass_query = construct_osm_amenity_query(date, area, amenity, out_type)
    response = requests.get(overpass_url, params={'data': overpass_query})
    data = response.json()
    return data["elements"]

# %%
def get_osm_amenity_count(date, area, amenity):
    data = get_osm_amenity_data(date, area, amenity, "count")
    str_count = data[0]['tags']['total']
    return int(str_count)

# %%
def get_yearly_amenity_count(years, area, amenity):
    yearly_counts = list()

    # Get count at the start of each month, then compute average
    for year in years:
        monthly_counts = list()

        for month in range(1, 13):
            str_month = str(month) if month > 9 else f"0{str(month)}"
            date = f"{year}-{str_month}-01T00:00:00Z"
            count = get_osm_amenity_count(date, area, amenity)
            monthly_counts.append(count)
            print(f"{amenity} count in {area} at {date}: {count}")

        yearly_count = statistics.mean(monthly_counts)
        yearly_counts.append(yearly_count)
        print(f"{year} {amenity} count in {area}: {yearly_count}")
        print("================")
        print()


    df = pd.DataFrame({'year': years, 'count': yearly_counts})
    return df

# %%
years = range(2013, 2025)
areas = ["London", "St_Albans", "Bath"]
amenities = ["cafe", "restaurant", "car_rental", "hotel"]

# %%
# for amenity_index in range(0, len(amenities)):
for amenity_index in range(1, len(amenities)):
    # for area_index in range(1, len(areas)):
    for area_index in range(1, 2):
        data = get_yearly_amenity_count(years, areas[area_index], amenities[amenity_index])
        data['amenity'] = amenities[amenity_index]
        data['area'] = areas[area_index]
        filepath = Path(f'../data/amenities/{areas[area_index]}/{amenities[amenity_index]}.csv')  
        filepath.parent.mkdir(parents=True, exist_ok=True)  
        data.to_csv(filepath, index=False)
# Out:
# restaurant count in St_Albans at 2013-01-01T00:00:00Z: 0
# restaurant count in St_Albans at 2013
01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-03-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-04-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-05-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-06-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-07-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-08-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-09-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-10-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-11-01T00:00:00Z: 62
# restaurant count in St_Albans at 2022-12-01T00:00:00Z: 62
# 2022 restaurant count in St_Albans: 61.75
# ================
#
# restaurant count in St_Albans at 2023-01-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-02-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-03-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-04-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-05-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-06-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-07-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-08-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-09-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-10-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-11-01T00:00:00Z: 62
# restaurant count in St_Albans at 2023-12-01T00:00:00Z: 62
# 2023 restaurant count in St_Albans: 62
# ================
#
# restaurant count in St_Albans at 2024-01-01T00:00:00Z: 65
# restaurant count in St_Albans at 2024-02-01T00:00:00Z: 65
# restaurant count in St_Albans at 2024-03-01T00:00:00Z: 65
# restaurant count in St_Albans at 2024-04-01T00:00:00Z: 66
# restaurant count in St_Albans at 2024-05-01T00:00:00Z: 66
# restaurant count in St_Albans at 2024-06-01T00:00:00Z: 66
# restaurant count in St_Albans at 2024-07-01T00:00:00Z: 66
# restaurant count in St_Albans at 2024-08-01T00:00:00Z: 66
# restaurant count in St_Albans at 2024-09-01T00:00:00Z: 66
# restaurant count in St_Albans at 2024-10-01T00:00:00Z: 65
# restaurant count in St_Albans at 2024-11-01T00:00:00Z: 64
# restaurant count in St_Albans at 2024-12-01T00:00:00Z: 64
# 2024 restaurant count in St_Albans: 65.33333333333333
# ================
#
# car_rental count in St_Albans at 2013-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-06-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-07-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-08-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-09-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-10-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-11-01T00:00:00Z: 0
# car_rental count in St_Albans at 2013-12-01T00:00:00Z: 0
# 2013 car_rental count in St_Albans: 0
# ================
#
# car_rental count in St_Albans at 2014-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-06-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-07-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-08-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-09-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-10-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-11-01T00:00:00Z: 0
# car_rental count in St_Albans at 2014-12-01T00:00:00Z: 0
# 2014 car_rental count in St_Albans: 0
# ================
#
# car_rental count in St_Albans at 2015-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-06-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-07-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-08-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-09-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-10-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-11-01T00:00:00Z: 0
# car_rental count in St_Albans at 2015-12-01T00:00:00Z: 0
# 2015 car_rental count in St_Albans: 0
# ================
#
# car_rental count in St_Albans at 2016-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-06-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-07-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-08-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-09-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-10-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-11-01T00:00:00Z: 0
# car_rental count in St_Albans at 2016-12-01T00:00:00Z: 0
# 2016 car_rental count in St_Albans: 0
# ================
#
# car_rental count in St_Albans at 2017-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-06-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-07-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-08-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-09-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-10-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-11-01T00:00:00Z: 0
# car_rental count in St_Albans at 2017-12-01T00:00:00Z: 0
# 2017 car_rental count in St_Albans: 0
# ================
#
# car_rental count in St_Albans at 2018-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-06-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-07-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-08-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-09-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-10-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-11-01T00:00:00Z: 0
# car_rental count in St_Albans at 2018-12-01T00:00:00Z: 0
# 2018 car_rental count in St_Albans: 0
# ================
#
# car_rental count in St_Albans at 2019-01-01T00:00:00Z: 0
# car_rental count in St_Albans at 2019-02-01T00:00:00Z: 0
# car_rental count in St_Albans at 2019-03-01T00:00:00Z: 0
# car_rental count in St_Albans at 2019-04-01T00:00:00Z: 0
# car_rental count in St_Albans at 2019-05-01T00:00:00Z: 0
# car_rental count in St_Albans at 2019-06-01T00:00:00Z: 3
# car_rental count in St_Albans at 2019-07-01T00:00:00Z: 3
# car_rental count in St_Albans at 2019-08-01T00:00:00Z: 3
# car_rental count in St_Albans at 2019-09-01T00:00:00Z: 3
# car_rental count in St_Albans at 2019-10-01T00:00:00Z: 3
# car_rental count in St_Albans at 2019-11-01T00:00:00Z: 3
# car_rental count in St_Albans at 2019-12-01T00:00:00Z: 3
# 2019 car_rental count in St_Albans: 1.75
# ================
#
# car_rental count in St_Albans at 2020-01-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-02-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-03-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-04-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-05-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-06-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-07-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-08-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-09-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-10-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-11-01T00:00:00Z: 3
# car_rental count in St_Albans at 2020-12-01T00:00:00Z: 3
# 2020 car_rental count in St_Albans: 3
# ================
#
# car_rental count in St_Albans at 2021-01-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-02-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-03-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-04-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-05-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-06-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-07-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-08-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-09-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-10-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-11-01T00:00:00Z: 3
# car_rental count in St_Albans at 2021-12-01T00:00:00Z: 3
# 2021 car_rental count in St_Albans: 3
# ================
#
# car_rental count in St_Albans at 2022-01-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-02-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-03-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-04-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-05-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-06-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-07-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-08-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-09-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-10-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-11-01T00:00:00Z: 3
# car_rental count in St_Albans at 2022-12-01T00:00:00Z: 3
# 2022 car_rental count in St_Albans: 3
# ================
#
# car_rental count in St_Albans at 2023-01-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-02-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-03-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-04-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-05-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-06-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-07-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-08-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-09-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-10-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-11-01T00:00:00Z: 4
# car_rental count in St_Albans at 2023-12-01T00:00:00Z: 4
# 2023 car_rental count in St_Albans: 4
# ================
#
# car_rental count in St_Albans at 2024-01-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-02-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-03-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-04-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-05-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-06-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-07-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-08-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-09-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-10-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-11-01T00:00:00Z: 4
# car_rental count in St_Albans at 2024-12-01T00:00:00Z: 4
# 2024 car_rental count in St_Albans: 4
# ================
#
# hotel count in St_Albans at 2013-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-06-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-07-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-08-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-09-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-10-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-11-01T00:00:00Z: 0
# hotel count in St_Albans at 2013-12-01T00:00:00Z: 0
# 2013 hotel count in St_Albans: 0
# ================
#
# hotel count in St_Albans at 2014-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-06-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-07-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-08-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-09-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-10-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-11-01T00:00:00Z: 0
# hotel count in St_Albans at 2014-12-01T00:00:00Z: 0
# 2014 hotel count in St_Albans: 0
# ================
#
# hotel count in St_Albans at 2015-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-06-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-07-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-08-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-09-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-10-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-11-01T00:00:00Z: 0
# hotel count in St_Albans at 2015-12-01T00:00:00Z: 0
# 2015 hotel count in St_Albans: 0
# ================
#
# hotel count in St_Albans at 2016-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-06-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-07-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-08-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-09-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-10-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-11-01T00:00:00Z: 0
# hotel count in St_Albans at 2016-12-01T00:00:00Z: 0
# 2016 hotel count in St_Albans: 0
# ================
#
# hotel count in St_Albans at 2017-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-06-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-07-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-08-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-09-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-10-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-11-01T00:00:00Z: 0
# hotel count in St_Albans at 2017-12-01T00:00:00Z: 0
# 2017 hotel count in St_Albans: 0
# ================
#
# hotel count in St_Albans at 2018-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-06-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-07-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-08-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-09-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-10-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-11-01T00:00:00Z: 0
# hotel count in St_Albans at 2018-12-01T00:00:00Z: 0
# 2018 hotel count in St_Albans: 0
# ================
#
# hotel count in St_Albans at 2019-01-01T00:00:00Z: 0
# hotel count in St_Albans at 2019-02-01T00:00:00Z: 0
# hotel count in St_Albans at 2019-03-01T00:00:00Z: 0
# hotel count in St_Albans at 2019-04-01T00:00:00Z: 0
# hotel count in St_Albans at 2019-05-01T00:00:00Z: 0
# hotel count in St_Albans at 2019-06-01T00:00:00Z: 9
# hotel count in St_Albans at 2019-07-01T00:00:00Z: 9
# hotel count in St_Albans at 2019-08-01T00:00:00Z: 9
# hotel count in St_Albans at 2019-09-01T00:00:00Z: 9
# hotel count in St_Albans at 2019-10-01T00:00:00Z: 9
# hotel count in St_Albans at 2019-11-01T00:00:00Z: 9
# hotel count in St_Albans at 2019-12-01T00:00:00Z: 9
# 2019 hotel count in St_Albans: 5.25
# ================
#
# hotel count in St_Albans at 2020-01-01T00:00:00Z: 9
# hotel count in St_Albans at 2020-02-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-03-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-04-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-05-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-06-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-07-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-08-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-09-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-10-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-11-01T00:00:00Z: 8
# hotel count in St_Albans at 2020-12-01T00:00:00Z: 8
# 2020 hotel count in St_Albans: 8.083333333333334
# ================
#
# hotel count in St_Albans at 2021-01-01T00:00:00Z: 8
# hotel count in St_Albans at 2021-02-01T00:00:00Z: 8
# hotel count in St_Albans at 2021-03-01T00:00:00Z: 8
# hotel count in St_Albans at 2021-04-01T00:00:00Z: 8
# hotel count in St_Albans at 2021-05-01T00:00:00Z: 8
# hotel count in St_Albans at 2021-06-01T00:00:00Z: 8
# hotel count in St_Albans at 2021-07-01T00:00:00Z: 7
# hotel count in St_Albans at 2021-08-01T00:00:00Z: 7
# hotel count in St_Albans at 2021-09-01T00:00:00Z: 7
# hotel count in St_Albans at 2021-10-01T00:00:00Z: 7
# hotel count in St_Albans at 2021-11-01T00:00:00Z: 6
# hotel count in St_Albans at 2021-12-01T00:00:00Z: 6
# 2021 hotel count in St_Albans: 7.333333333333333
# ================
#
# hotel count in St_Albans at 2022-01-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-02-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-03-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-04-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-05-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-06-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-07-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-08-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-09-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-10-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-11-01T00:00:00Z: 6
# hotel count in St_Albans at 2022-12-01T00:00:00Z: 6
# 2022 hotel count in St_Albans: 6
# ================
#
# hotel count in St_Albans at 2023-01-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-02-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-03-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-04-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-05-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-06-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-07-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-08-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-09-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-10-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-11-01T00:00:00Z: 6
# hotel count in St_Albans at 2023-12-01T00:00:00Z: 6
# 2023 hotel count in St_Albans: 6
# ================
#
# hotel count in St_Albans at 2024-01-01T00:00:00Z: 6
# hotel count in St_Albans at 2024-02-01T00:00:00Z: 6
# hotel count in St_Albans at 2024-03-01T00:00:00Z: 6
# hotel count in St_Albans at 2024-04-01T00:00:00Z: 6
# hotel count in St_Albans at 2024-05-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-06-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-07-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-08-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-09-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-10-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-11-01T00:00:00Z: 5
# hotel count in St_Albans at 2024-12-01T00:00:00Z: 5
# 2024 hotel count in St_Albans: 5.333333333333333
# ================
