# %%
import os
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
from rapidfuzz import fuzz
import sys
from multiprocessing import Pool

# %%
country_crs_mapping = {
    'albania': 32634,
    'kosovo': 32634,
    'andorra': 32631,
    'latvia': 32635,
    'austria': 32633,
    'liechtenstein': 32632,
    'azores': 32626,
    'lithuania': 32635,
    'belarus': 32635,
    'luxembourg': 32631,
    'belgium': 32631,
    'macedonia': 32634,
    'bosnia-herzegovina': 32633,
    'malta': 32633,
    'bulgaria': 32635,
    'moldova': 32635,
    'croatia': 32633,
    'monaco': 32632,
    'cyprus': 32636,
    'montenegro': 32634,
    'czech-republic': 32633,
    'netherlands': 32631,
    'denmark': 32632,
    'norway': 32632,
    'estonia': 32635,
    'poland': 32634,
    'faroe-islands': 32629,
    'portugal': 32629,
    'finland': 32635,
    'romania': 32635,
    'france': 32631,  # Defaulting to Western France
    'russia': 32636,  # Defaulting to Western Russia
    'georgia': 32638,
    'serbia': 32634,
    'germany': 32632,  # Defaulting to Western Germany
    'slovakia': 32633,
    'greece': 32634,  # Defaulting to Western Greece
    'slovenia': 32633,
    'guernsey-jersey': 32630,
    'spain': 32630,  # Defaulting to Western Spain
    'hungary': 32634,
    'sweden': 32633,  # Defaulting to Southern Sweden
    'iceland': 32627,
    'switzerland': 32632,
    'ireland-and-northern-ireland': 32629,
    'turkey': 32636,
    'isle-of-man': 32630,
    'ukraine': 32636,
    'italy': 32632,  # Defaulting to Western Italy
    'united-kingdom': 32630
}

# %%
def clean_polygons(df, threshold=80):
    overlapping = gpd.sjoin(df, df, how='inner') # overlapping polygons
    overlapping = overlapping[overlapping.id_left != overlapping.id_right] # remove self joins
    overlapping = overlapping[overlapping.id_left < overlapping.id_right] # remove swapped orders e.g. (A,B) and (B,A)
    if "name_left" in overlapping.columns and "name_right" in overlapping.columns:
        overlapping["similarity_score"] = overlapping.apply(
            lambda row: fuzz.ratio(row["name_left"], row["name_right"]), axis=1
        )
        duplicates = overlapping[overlapping["similarity_score"] > threshold] # overlapping and similar name
    else:
        duplicates = overlapping

    duplicates["keep_id"] = duplicates.apply(
        lambda row: row["id_left"] if row["tag_count_left"] >= row["tag_count_right"] else row["id_right"],
        axis=1
    )
    to_remove = duplicates.apply(
        lambda row: row["id_right"] if row["keep_id"] == row["id_left"] else row["id_left"],
        axis=1
    )
    cleaned_df = df.loc[~df["id"].isin(to_remove)].copy()
    return cleaned_df

# %%
def clean_points(points, polygons):
    """
    Deduplicates the given DataFrame based on overlap with an existing polygon.
    Args:
        points (gpd.DataFrame): GeoDataFrame to deduplicate
        polygons (gpd.DataFrame): GeoDataFrame to base deduplication on
    Returns:
        gpd.DataFrame: Deduplicated GeoDataFrame
    """
    points_in_polygons = points.sjoin(polygons, how="inner", predicate="within")
    to_remove = points_in_polygons.index
    cleaned_df = points.loc[~points.index.isin(to_remove)].copy()
    return cleaned_df

# %%
def deduplicate_data(gdf):
    """
    Deduplicates the given DataFrame.
    Args:
        gdf (gpd.DataFrame): GeoDataFrame to deduplicate
    Returns:
        gpd.DataFrame: Deduplicated GeoDataFrame
    """
    country = gdf['country'].iloc[0].lower()  # Assumes all rows in gdf belong to one country
    target_epsg = country_crs_mapping.get(country, 3035)  # Default to EPSG:3035 for Europe

    # Transform GeoDataFrame to the appropriate CRS
    gdf = gdf.to_crs(epsg=target_epsg)
    
    gdf_points = gdf[gdf.geometry.type == "Point"].copy()
    gdf_polygons = gdf[gdf.geometry.type.isin(["LineString", "MultiPolygon"])].copy() # way or area
    polygons_clean = None
    points_clean = None

    # Process polygons if any exist
    if not gdf_polygons.empty:
        polygons_clean = clean_polygons(gdf_polygons)
        # Convert polygon centroids to points
        polygons_clean["geometry"] = polygons_clean.centroid
    
    # Process points if any exist
    if not gdf_points.empty:
        # If polygons_clean exists, use it for filtering; otherwise, skip filtering
        if polygons_clean is not None:
            points_clean = clean_points(gdf_points, polygons_clean)
        else:
            points_clean = gdf_points
        
    return polygons_clean, points_clean

# %%
def process_to_features(gdf):
    gdf = gdf.to_crs(4326)
    #gdf['lat'] = gdf['geometry'].y
    #gdf['long'] = gdf['geometry'].x
    if 'wikimedia_commons' in gdf.columns:
        gdf['has_wikimedia_commons'] = gdf['wikimedia_commons'].notnull().astype(int)
    else:
        gdf['has_wikimedia_commons'] = 0
        
    if 'wikipedia' in gdf.columns:
        gdf['has_wikipedia'] = gdf['wikipedia'].notnull().astype(int)
    else:
        gdf['has_wikipedia'] = 0
    
    #gdf = gdf.drop(labels=["geometry"], axis=1)
    #gdf["geometry"] = gpd.GeoSeries.from_wkt(gdf["geometry"])
    columns_to_keep = ['id', 'name', 'tag_count', 'geometry', 'has_wikimedia_commons', 'has_wikipedia', 'country', 'tag_key', 'tag_value'] # memory fix
    gdf = gdf.loc[:, [col for col in columns_to_keep if col in gdf.columns]]
    return gdf

# %%
def process_file(args):
    """
    Loads and deduplicates a single GeoJSON file.
    Args:
        file_path (str): Path to the GeoJSON file
    Returns:
        pd.DataFrame: Deduplicated DataFrame
    """
    file_path, file_name = args
    print(f"Processing {file_path}...")
    gdf = gpd.read_file(file_path)
    if gdf.empty:
        print(f"File {file_path} is empty, skipping...")
        return None
    country, key, value = extract_values_from_filename(file_name)
    gdf["tag_count"] = gdf.apply(
        lambda row: row.notna().sum() - 3, axis=1 # count tags other than id, name, geometry
    )
    gdf["country"] = country
    gdf["tag_key"] = key
    gdf["tag_value"] = value
    columns_to_keep = ['id', 'name', 'tag_count', 'geometry', 'wikimedia_commons', 'wikipedia', 'country', 'tag_key', 'tag_value'] # memory fix
    gdf = gdf.loc[:, [col for col in columns_to_keep if col in gdf.columns]]
    polygons, points = deduplicate_data(gdf)

    if polygons is not None and not polygons.empty and points is not None and not points.empty:
        polygons["geometry"] = polygons.centroid
        final_gdf = pd.concat([points, polygons], ignore_index=True)
        return process_to_features(final_gdf)
    
    if polygons is not None and not polygons.empty and points is None:
        print("empty points but polygons")
        return process_to_features(polygons)
    
    if polygons is None and points is not None and not points.empty:
        print("empty polygons but points")
        return process_to_features(points)
    
    if polygons is None and points is None:
        print("both empty")
        return None

# %%
def extract_metadata_from_filename(file_name):
    """
    Extract metadata (country, key, value) from the file name.
    Args:
        file_name (str): File name to parse.
    Returns:
        tuple: Extracted (country, key, value) as strings.
    """
    base_name = file_name.replace(".geojson", "")
    parts = base_name.split("-")
    
    # Ensure the file name has enough parts to extract meaningful metadata
    if len(parts) < 4:
        raise ValueError(f"File name {file_name} is not in the expected format.")
    
    country = parts[0]  # e.g., 'austria'
    key = parts[-2]     # e.g., 'craft'
    value = parts[-1]   # e.g., 'handicraft'
    
    return country, key, value

# %%
def extract_values_from_filename(filename: str) -> tuple[str, str, str]:
    """
    Given a filename of the format:

        <country>-latest-keys-<key>-<value>.geojson

    where:
        - country can have 1 or more words (joined by '-')
        - "latest" and "keys" are fixed markers and not extracted
        - key is exactly 1 word
        - value can have 1 or more words (joined by '-')

    This function returns a tuple of (country, key, value).

    Examples:
        "guernsey-jersey-latest-keys-amenity-exhibition-centre.geojson" 
            -> ("guernsey-jersey", "amenity", "exhibition-centre")
        "macedonia-latest-keys-building-military.geojson"
            -> ("macedonia", "building", "military")

    :param filename: The filename to parse (with or without the .geojson extension).
    :return: A tuple (country, key, value).
    """
    # Strip out the extension if present (e.g., .geojson)
    base_name = os.path.splitext(filename)[0]

    # Split on '-'
    parts = base_name.split('-')

    # Find the index of 'latest'; we assume 'keys' comes immediately after
    # This is a simplified assumption based on known format:
    #   [country (1..n parts)]-latest-keys-[key (1 part)]-[value (1..n parts)]
    try:
        latest_idx = parts.index('latest')
    except ValueError:
        raise ValueError(f"'latest' not found in filename: {filename}")

    # country is everything before 'latest'
    country_parts = parts[:latest_idx]
    if not country_parts:
        raise ValueError(f"No country name found before 'latest' in filename: {filename}")
    country = '-'.join(country_parts)

    # skip 'latest' and the next part should be 'keys'
    # so the key should be after "latest" and "keys"
    # i.e. at index `latest_idx + 2`
    if len(parts) < latest_idx + 3:
        raise ValueError(f"Filename does not have enough parts to extract key and value: {filename}")
    if parts[latest_idx + 1] != 'keys':
        raise ValueError(f"Expected 'keys' after 'latest' in filename: {filename}")

    key = parts[latest_idx + 2]

    # The remainder (if any) is the value (can have 1 or more words)
    value_parts = parts[latest_idx + 3:]
    if not value_parts:
        raise ValueError(f"No value part found in filename: {filename}")
    value = '-'.join(value_parts)

    return country, key, value

# %%
def consolidate_files(directory, processes):
    """
    Processes all files in a directory, adds metadata from filenames, 
    and consolidates them into a single DataFrame.
    Args:
        directory (str): Directory containing GeoJSON files.
    Returns:
        pd.DataFrame: Consolidated and deduplicated DataFrame with metadata.
    """
    files = [
        (os.path.join(directory, file_name), file_name)
        for file_name in os.listdir(directory)
        if file_name.endswith(".geojson")
    ]
    with Pool(processes=processes) as pool:
        results = pool.map(process_file, files)

    filtered_list = [x for x in results if x is not None]
    
    consolidated_df = gpd.GeoDataFrame(pd.concat(filtered_list, ignore_index=True), crs=filtered_list[0].crs if filtered_list else None)
    return consolidated_df

# %%
pd.options.mode.copy_on_write = True
consolidated_data = consolidate_files("/home/m4/dataprog/dataprog/austria-poi", int(12))
#final_data
#consolidated_data = consolidate_files("/home/m4/dataprog/dataprog/pois")
#consolidated_data.to_file("consolidated_pois.geojson", driver="GeoJSON")
# Out:
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-atelier.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-conservatory.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-monastery.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-meteor-crater.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-castle.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-gallows.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-bar.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-locomotive.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-jeweller.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-temple.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-taxi.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-hot-spring.geojson...
#
#
#
#
#
#
#
#
#
#
#
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-temple.geojson is empty, skipping...File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-meteor-crater.geojson is empty, skipping...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-watchmaker.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-clock.geojson...
#
# empty polygons but points
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-exhibition-centre.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-music-venue.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-creamery.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-beekeeper.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-industrial.geojson...
#
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-aerialway-station.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-conference-centre.geojson...
#
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-creamery.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-confectionery.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-handicraft.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-casino.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-fold.geojson...
#
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-mint.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-fold.geojson is empty, skipping...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-tower.geojson...
#
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-mint.geojson is empty, skipping...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-bicycle-rental.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-grandstand.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-fountain.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-train-station.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-refugee-site.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-place-of-worship.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-retail.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-fault.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-fault.geojson is empty, skipping...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-manor.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-city-gate.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-railway-subway-entrance.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-viewpoint.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-distillery.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-commercial.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-volcano.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-bay.geojson...
#
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-volcano.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-public-transport-station.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-cafe.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-sinkhole.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-post-office.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-sinkhole.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-water-lake.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-grave-yard.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-boat-rental.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-bus-station.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-attraction.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-gallery.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-government.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-building.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-university.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-car-rental.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-office.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-university.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-surf-school.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-surf-school.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-monument.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-geyser.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-geyser.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-post-box.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-stable.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-farm.geojson...
# empty points but polygons
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-machine.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-anchor.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-police.geojson...
#
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-anchor.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-beach.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-waterway-dam.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-shop-gift.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-pottery.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-wreck.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-theme-park.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-columnar-jointing.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-columnar-jointing.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-battlefield.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-high-cross.geojson...empty polygons but points
#
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-archaeological-site.geojson...File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-high-cross.geojson is empty, skipping...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-bunker.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-charging-station.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-stadium.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-military.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-peak.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-supermarket.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-museum.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-cannon.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-church.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-brewery.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-cinema.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-house.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-artwork.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-zoo.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-aquarium.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-fort.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-tailor.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-atm.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-funeral-hall.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-sport-motor.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-townhall.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-tomb.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-theatre.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-religious.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-restaurant.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-stage.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-stage.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-volcanic-vent.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-volcanic-vent.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-ruins.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-nightclub.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-tower.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-bridge.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-bakehouse.geojson...
# empty points but polygons
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-recycling.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-valley.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-arch.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-blacksmith.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-glassblower.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-civic.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-pub.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-mine.geojson...
# Skipping field smoking_hours: unsupported OGR type: 10
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-windmill.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-windmill.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-memorial.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-tourism-museum.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-goldsmith.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-aeroway-terminal.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-winery.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-monastery.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-ruins.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-natural-glacier.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-cathedral.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-event-venue.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-event-venue.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-castle.geojson...Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-bank.geojson...
#
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-amenity-internet-cafe.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-barn.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-shoemaker.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-public.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-aircraft.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-ship.geojson...
# empty points but polygons
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-craft-clockmaker.geojson...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-aqueduct.geojson...
# empty points but polygons
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-tor.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-geological-tor.geojson is empty, skipping...
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-historic-tank.geojson...
# empty polygons but points
# Processing /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-pagoda.geojson...
# File /home/m4/dataprog/dataprog/austria-poi/austria-latest-keys-building-pagoda.geojson is empty, skipping...

# %%
print(consolidated_data.sort_values(by=['tag_count'], ascending=False).head(n=20))
# Out:
#                  id                        name  tag_count  \
# 14144    a424992922                 Stephansdom         62
# 3509     a424992922                 Stephansdom         62
# 27295    a424992922                 Stephansdom         62
# 94463    a381966600                        Spar         51
# 65760    a128910134  Restaurant am Salzburgring         49
# 67302    a257327096   Pizzeria Trattoria Romana         47
# 105556  a1628227212              ASZ Vorderland         45
# 94439    a310816942                        Spar         45
# 47275    a166401670        Bregenzer Sporthafen         43
# 67461    a263813744               Douglasshütte         41
# 48002      a2313693                    Bodensee         41
# 44463   n8214584375            die Tauplitzerin         40
# 26888     a16194298                 Karlskirche         40
# 9801      a16194298                 Karlskirche         40
# 38052    a962267406                         MOL         40
# 104949  n8814033396                Recyclinghof         39
# 68632    a345019386      Pizzeria Bruno Tinello         39
# 94174        a40331    Kunsthistorisches Museum         39
# 65593     a78230502                    Zollwirt         39
# 68118    a306377512            die Tauplitzerin         39
#
#                          geometry  has_wikimedia_commons  has_wikipedia  \
# 14144   POINT (16.37317 48.20848)                      1              1
# 3509    POINT (16.37317 48.20848)                      1              1
# 27295   POINT (16.37317 48.20848)                      1              1
# 94463   POINT (10.97788 47.30564)                      0              0
# 65760   POINT (13.17433 47.82393)                      0              0
# 67302    POINT (9.64811 47.30531)                      0              0
# 105556   POINT (9.62272 47.30152)                      0              0
# 94439   POINT (10.92738 47.29766)                      0              0
# 47275    POINT (9.72701 47.50662)                      0              0
# 67461     POINT (9.7547 47.05966)                      0              1
# 48002    POINT (9.37999 47.61245)                      0              1
# 44463   POINT (14.01269 47.56241)                      0              0
# 26888   POINT (16.37187 48.19829)                      1              1
# 9801    POINT (16.37187 48.19829)                      1              1
# 38052   POINT (16.28264 46.98176)                      0              0
# 104949  POINT (13.01224 47.80365)                      0              0
# 68632    POINT (9.65138 47.29838)                      0              0
# 94174   POINT (16.36178 48.20374)                      0              1
# 65593   POINT (12.29893 46.91227)                      0              0
# 68118   POINT (14.01248 47.56242)                      0              0
#
#         country   tag_key         tag_value
# 14144   austria   amenity  place-of-worship
# 3509    austria  building         cathedral
# 27295   austria   tourism        attraction
# 94463   austria  building       supermarket
# 65760   austria   amenity        restaurant
# 67302   austria   amenity        restaurant
# 105556  austria   amenity         recycling
# 94439   austria  building       supermarket
# 47275   austria     water              lake
# 67461   austria   amenity        restaurant
# 48002   austria     water              lake
# 44463   austria   amenity              cafe
# 26888   austria   tourism        attraction
# 9801    austria   amenity  place-of-worship
# 38052   austria  building            retail
# 104949  austria   amenity         recycling
# 68632   austria   amenity        restaurant
# 94174   austria  building            museum
# 65593   austria   amenity        restaurant
# 68118   austria   amenity        restaurant
